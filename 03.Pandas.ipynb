# %% [markdown]
# # Pandas

# %%
#importamos librerias
import pandas as pd
import os
from pathlib import Path

# %%
# cargamos la data en un DF

root=Path(".").resolve()
filename="apple_quality.csv"
pathdata=os.path.join(root,'data','raw',filename)

#Leemos el archivo
df=pd.read_csv(pathdata)
df.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
df['Quality'][2]
# Out:
# 'bad'

# %%
df.iloc[0]
# Out:
# A_id                    0.0
# Size              -3.970049
# Weight            -2.512336
# Sweetness           5.34633
# Crunchiness       -1.012009
# Juiciness            1.8449
# Ripeness            0.32984
# Acidity        -0.491590483
# Quality                good
# Name: 0, dtype: object

# %%
df.iloc[:,0]
# Out:
# 0          0.0
# 1          1.0
# 2          2.0
# 3          3.0
# 4          4.0
#          ...
# 3996    3996.0
# 3997    3997.0
# 3998    3998.0
# 3999    3999.0
# 4000       NaN
# Name: A_id, Length: 4001, dtype: float64

# %%
df.iloc[:3,0]
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# Name: A_id, dtype: float64

# %%
df.iloc[[1,200,4000],0]
# Out:
# 1         1.0
# 200     200.0
# 4000      NaN
# Name: A_id, dtype: float64

# %%
df.iloc[:,:-5]
# Out:
#         A_id      Size    Weight  Sweetness
# 0        0.0 -3.970049 -2.512336   5.346330
# 1        1.0 -1.195217 -2.839257   3.664059
# 2        2.0 -0.292024 -1.351282  -1.738429
# 3        3.0 -0.657196 -2.271627   1.324874
# 4        4.0  1.364217 -1.296612  -0.384658
# ...      ...       ...       ...        ...
# 3996  3996.0 -0.293118  1.949253  -0.204020
# 3997  3997.0 -2.634515 -2.138247  -2.440461
# 3998  3998.0 -4.008004 -1.779337   2.366397
# 3999  3999.0  0.278540 -1.715505   0.121217
# 4000     NaN       NaN       NaN        NaN
#
# [4001 rows x 4 columns]

# %%
df.loc[0,'Quality']
# Out:
# 'good'

# %%
df.loc[:,['Quality','Size','Weight']]
# Out:
#      Quality      Size    Weight
# 0       good -3.970049 -2.512336
# 1       good -1.195217 -2.839257
# 2        bad -0.292024 -1.351282
# 3       good -0.657196 -2.271627
# 4       good  1.364217 -1.296612
# ...      ...       ...       ...
# 3996    good -0.293118  1.949253
# 3997     bad -2.634515 -2.138247
# 3998    good -4.008004 -1.779337
# 3999    good  0.278540 -1.715505
# 4000     NaN       NaN       NaN
#
# [4001 rows x 3 columns]

# %%
df.Quality == 'good'
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 3996     True
# 3997    False
# 3998     True
# 3999     True
# 4000    False
# Name: Quality, Length: 4001, dtype: bool

# %%
df.loc[df.Quality == 'bad']
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 5        5.0 -3.425400 -1.409082  -1.913511    -0.555775  -3.853071  1.914616
# 8        8.0 -3.867632 -3.734514   0.986429    -1.207655   2.292873  4.080921
# 9        9.0 -0.727983 -0.442820  -4.092223     0.597513   0.393714  1.620857
# 10      10.0 -2.699336 -1.329507  -1.418507    -0.625546   2.371074  3.403165
# ...      ...       ...       ...        ...          ...        ...       ...
# 3989  3989.0 -2.282625 -0.225517  -1.698524     0.936855  -1.385481  3.249894
# 3990  3990.0 -1.396794 -0.599596  -1.931104     1.815668   1.670732  1.614027
# 3993  3993.0  1.520142 -0.352623  -3.206467     1.341719   0.675568  0.107093
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
#
#            Acidity Quality
# ...

# %%
df.loc[(df['Quality']=='bad')& (df.Size >4)]
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 1301  1301.0  4.123222 -1.651736  -0.554216     3.838873  -3.748403 -3.931116
# 2262  2262.0  4.102549 -1.532028   1.739175     3.508420  -3.581638 -3.467742
# 3494  3494.0  4.649923 -1.675508  -3.241841     5.333283  -4.830750 -3.811951
# 3957  3957.0  4.086332  0.601599   0.934812     5.780529  -2.627074 -4.676170
#
#            Acidity Quality
# 1301   -0.33283833     bad
# 2262   1.811772403     bad
# 3494  -0.518724707     bad
# 3957   4.689126107     bad

# %%
df.loc[df['A_id'].isin([400])]
# Out:
#       A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 400  400.0 -1.455035 -0.094437  -1.810407     0.631184   2.116622 -2.282722
#
#           Acidity Quality
# 400  -1.590347457    good

# %%
df.loc[df.Quality.notnull()]
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# ...

# %%
df.loc[df.Quality.isna()]
# Out:
#       A_id  Size  Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 4000   NaN   NaN     NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 4000  Created_by_Nidula_Elgiriyewithana     NaN

# %%
df.loc[df.Quality == 'good',['Quality']]='Bueno'
df.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483   Bueno
# 1  -0.722809367   Bueno
# 2   2.621636473     bad
# 3   0.790723217   Bueno
# 4   0.501984036   Bueno

# %%
df['rankr']=range(0,len(df),1)
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
help('range')
# Out:
# Help on class range in module builtins:
#
# class range(object)
#  |  range(stop) -> range object
#  |  range(start, stop[, step]) -> range object
#  |
#  |  Return an object that produces a sequence of integers from start (inclusive)
#  |  to stop (exclusive) by step.  range(i, j) produces i, i+1, i+2, ..., j-1.
#  |  start defaults to 0, and stop is omitted!  range(4) produces 0, 1, 2, 3.
#  |  These are exactly the valid indices for a list of 4 elements.
#  |  When step is given, it specifies the increment (or decrement).
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
# ...
